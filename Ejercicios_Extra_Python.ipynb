# %% [markdown]
# <a href="https://colab.research.google.com/github/dgordiales/DS-Online-Dani-Garcia-Ordiales/blob/main/Ejercicios_Extra_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON EXTRA:

# %% [markdown]
# Los siguientes ejercicios son para que practiques por tu cuenta si te apetece. No es obligatorio hacerlo, pero seguramente te divertirás practicando con ellos. Si quieres la solución, no te cortes, y pídela :-)

# %% [markdown]
# ## Ejercicio 1
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10

# %%
in1 = input("Introduce un número por favor: ")
in2 = input("Introduce otro: ")
suma = int(in1) + int(in2)
if suma==10:
  ptint("Los números suman 10")
elif suma  >10:
    print("La suma de los números es mayor que 10")
else:
      print("La suma de los números es inferior a 10")
# Out:
# Introduce un número por favor: 1
# Introduce otro: 1
# La suma de los números es inferior a 10

# %% [markdown]
# ## Ejercicio 2
# Solicite al usuario dos números enteros usando la función input. Calcule la suma de estos dos números y muestre el resultado. Recuerde convertir adecuadamente los tipos de datos.

# %%
int1 = int(input("Introduce un número por favor: "))
int2 = int(input("Introduce otro: "))
print("La suma de los números es",int1 + int2)
# Out:
# Introduce un número por favor: 0
# Introduce otro: 5
# La suma de los números es 5

# %% [markdown]
# ## Ejercicio 3
# Sobre el programa del ejercicio anterior, y recordando el que se hizo en el workout para saber si un número es par, comprueba si alguno de los números introducidos por el usuario es multiplo del otro

# %% [markdown]
# Recuerda el código que vimos en la sesión online del workout:
# ```Python
# n = 23
# print("¿Es",n,"par?")
# resto = n%2
# print("El resto es", resto)
# # Si queremos que nos haga el las comparaciones usaremos el comando if, adelantándonos un poco
# if resto == 0:
#     print("Es par")
# else:
#     print("Es impar")
# ```

# %%
resto1= int1%int2
resto2 = int2%int1

if resto1 == 0 and resto2 == 0:
  print("Ambos son multiplos del otro.")
elif resto1 != 0 and resto2 == 0:
  print(int2,"es múltiplo de",int1)
elif resto1 == 0 and resto2 != 0:
  print(int1,"es múltiplo de",int2)
else :
  print("Ninguno es múltiplo del otro.")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_638/3633281926.py in <cell line: 0>()
#       1 resto1= int1%int2
# ----> 2 resto2 = int2%int1
#       3
#       4 if resto1 == 0 and resto2 == 0:
#       5   print("Ambos son multiplos del otro.")
#
# ZeroDivisionError: integer modulo by zero

# %% [markdown]
# ## Ejercicio 4
#
# Introduce el 0 como valor en uno de los inputs en el programa anterior y comprueba que sucede. Explica el resultado

# %%
# No se puede dividir por 0 porque el resultado siempre es 0.

# %% [markdown]
# ## Ejercicio 5
#
# 1. Convierte la frase "La primera vez que conocí a Terry Lenox" en una lista de palabras.
# 2. Cambia de dos formas diferentes "Terry" por "John".
# 3. Ordena alfabéticamente la lista resultante.
# 4. Investiga sobre el método join de los strings, y convierte la lista de nuevo en un string con las palabras separadas por espacios. Para ello empieza practicando (en otra celda):
#     ```Python
#     "\n".join(["Primera linea","segunda linea","tercera linea])
#     ```
#
# 5. Pasa el string resultante a mayúsculas e imprímelo.

# %%
str = "La primera vez que conocí a Terry Lenox"
lista = str.split()
print(lista)
lista.sort()
print(lista)
n = " ".join(lista)
print(n.upper())
# Out:
# ['La', 'primera', 'vez', 'que', 'conocí', 'a', 'Terry', 'Lenox']
# ['La', 'Lenox', 'Terry', 'a', 'conocí', 'primera', 'que', 'vez']
# LA LENOX TERRY A CONOCÍ PRIMERA QUE VEZ
